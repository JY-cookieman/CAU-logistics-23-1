# %% [markdown]
# # Module 3: Data Exploration
#
# The following tutorial contains **examples of Python code for data exploration**. Read the step-by-step instructions below carefully. To execute the code, click on the cell and press the SHIFT-ENTER keys simultaneously.

# %% [markdown]
# Data exploration refers to the preliminary investigation of data in order
# to better understand its specific characteristics. There are two key motivations for data exploration:
# 1. To help users select the appropriate preprocessing and data analysis technique used.
# 2. To make use of humans’ abilities to recognize patterns in the data.

# %% [markdown]
# #### Import packages

# %%
# jupyter-notebook-specific command:
# shows the plots without `plt.show()` in Jupyter notebook
# %matplotlib inline

# import packages
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# increase default figure and font sizes for easier viewing
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %% [markdown]
# In this tutorial, we will explore [Iris dataset](http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data) from the UCI machine learning repository. This data contain information on 150 Iris flowers, 50 each from one of three Iris species: Setosa, Versicolour, and Virginica. Each flower is characterized by five attributes:
#
# - sepal length in centimeters
#
# - sepal width in centimeters
#
# - petal length in centimeters
#
# - petal width in centimeters
#
# - class (Setosa, Versicolour, Virginica)
#
# **<font color="red">Code:</font>** The following code uses Pandas to read the CSV file and store them in a DataFrame object named `data`. Next, it will display the first five rows of the data frame using `.head()`.

# %%
data = pd.read_csv('Iris.csv')
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# The following code changes the column names for brevity.

# %%
data.columns = ['sepal length', 'sepal width', 'petal length', 'petal width', 'class']

data.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## 3.1. Summary Statistics
#
# Summary statistics are quantities, such as the mean and standard deviation, that capture various characteristics of a potentially large set of values with a single number or a small set of numbers.
#
# In this tutorial, you will learn how to compute various summary statistics from the DataFrame.
#
# To execute the sample program shown here, make sure you have installed the Pandas library (see Module 2).

# %% [markdown]
# **1.** For each quantitative attribute, calculate its average, standard deviation, minimum, and maximum values.
#
# **<font color="red">Code:</font>**

# %%
for col in ['sepal length', 'sepal width', 'petal length', 'petal width']:
    print('%s:' % (col))
    print('\t Mean = %.2f' % data[col].mean())
    print('\t Standard deviation = %.2f' % data[col].std())
    print('\t Minimum = %.2f' % data[col].min())
    print('\t Maximum = %.2f' % data[col].max())
# Out:
# sepal length:
# 	 Mean = 5.84
# 	 Standard deviation = 0.83
# 	 Minimum = 4.30
# 	 Maximum = 7.90
# sepal width:
# 	 Mean = 3.05
# 	 Standard deviation = 0.43
# 	 Minimum = 2.00
# 	 Maximum = 4.40
# petal length:
# 	 Mean = 3.76
# 	 Standard deviation = 1.76
# 	 Minimum = 1.00
# 	 Maximum = 6.90
# petal width:
# 	 Mean = 1.20
# 	 Standard deviation = 0.76
# 	 Minimum = 0.10
# 	 Maximum = 2.50

# %% [markdown]
# **2.** For the qualitative attribute (class), count the frequency for each of its distinct values.
#
# **<font color="red">Code:</font>**

# %%
data['class'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: class, dtype: int64

# %% [markdown]
# **3.** It is also possible to display the summary for all the attributes simultaneously in a table using the describe() function. If an attribute is quantitative, it will display its mean, standard deviation and various quantiles (including minimum, median, and maximum) values. If an attribute is qualitative, it will display its number of unique values and the top (most frequent) values.
#
# **<font color="red">Code:</font>**

# %%
data.describe(include='all')
# Out:
#         sepal length  sepal width  petal length  petal width        class
# count     150.000000   150.000000    150.000000   150.000000          150
# unique           NaN          NaN           NaN          NaN            3
# top              NaN          NaN           NaN          NaN  Iris-setosa
# freq             NaN          NaN           NaN          NaN           50
# mean        5.843333     3.054000      3.758667     1.198667          NaN
# std         0.828066     0.433594      1.764420     0.763161          NaN
# min         4.300000     2.000000      1.000000     0.100000          NaN
# 25%         5.100000     2.800000      1.600000     0.300000          NaN
# 50%         5.800000     3.000000      4.350000     1.300000          NaN
# 75%         6.400000     3.300000      5.100000     1.800000          NaN
# max         7.900000     4.400000      6.900000     2.500000          NaN

# %% [markdown]
# Note that count refers to the number of non-missing values for each attribute.

# %% [markdown]
# **4.** For multivariate statistics, you can compute the covariance and correlation between pairs of attributes.
#
# **<font color="red">Code:</font>**

# %%
print('Correlation:')
data.corr()
# Out:
# Correlation:
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.109369      0.871754     0.817954
# sepal width      -0.109369     1.000000     -0.420516    -0.356544
# petal length      0.871754    -0.420516      1.000000     0.962757
# petal width       0.817954    -0.356544      0.962757     1.000000

# %% [markdown]
# ## 3.2. Data Visualization
#
# Data visualization is the display of information in a graphic or tabular format. Successful visualization requires that the data (information) be converted into a visual format so that the characteristics of the data and the relationships among data items or attributes can be analyzed or reported.
#
# In this tutorial, you will learn how to display the Iris data. To execute the sample program shown here, make sure you have installed the `matplotlib` library package.

# %% [markdown]
# Befor visualization, you need to import the `matplotlib` package.

# %% [markdown]
# **1.** First, we will display the histogram for the sepal length attribute by discretizing it into 8 separate bins and counting the frequency for each bin.
#
# **<font color="red">Code:</font>**

# %%
plt.hist(data['sepal width'], bins=8)
# data['sepal width'].hist(bins=8) # do the same thing as above
plt.xlabel('sepal width')
plt.ylabel('count')
plt.title('Histogram of sepal width')
plt.show()

# %% [markdown]
# **2.** A boxplot can also be used to show the distribution of values for each attribute.
#
# **<font color="red">Code:</font>**

# %%
plt.boxplot(data.iloc[:, :-1])
# data.boxplot() # do the same thing as above
plt.xlabel('column')
plt.ylabel('value')
plt.title('Box plot of Iris')
plt.show()

# %% [markdown]
# **3.** For each pair of attributes, we can use a scatter plot to visualize their joint distribution.
#
# **<font color="red">Code:</font>**

# %%
x = 'petal width'
y = 'petal length'

plt.scatter(data[x], data[y])

plt.xlabel(x)
plt.ylabel(y)
plt.title('Scatter plot')
plt.show()

# %%
# Scatter matrix
fig, axes = plt.subplots(4, 4, figsize=(12, 12)) # 4 x 4 plots in a figure

for i in range(4):
    col_i = data.columns[i]
    for j in range(4):
        col_j = data.columns[j]
        if j == i:
            axes[i][j].hist(data[col_i], bins=10)
            axes[i][j].set_xlabel(col_i)
            axes[i][j].set_ylabel('count')
        else:
            axes[i][j].scatter(data[col_i], data[col_j])
            axes[i][j].set_xlabel(col_i)
            axes[i][j].set_ylabel(col_j)
plt.tight_layout()

# %% [markdown]
# You can obtain the same result with only one line below:

# %%
pd.plotting.scatter_matrix(data[data.columns[:4]], figsize=(12, 12))
plt.show()

# %% [markdown]
# You can save a plot to a file.

# %%
data['sepal width'].plot(kind='hist', bins=20, title='Histogram of Sepal Width')
plt.xlabel('Sepal Width')
plt.ylabel('Frequency')
plt.savefig('sepal_width_histogram.png')

# %% [markdown]
# You can use `seaborn` package. Easy usage, awesome output.
#
# Example gallery: https://seaborn.pydata.org/examples/index.html

# %%
import seaborn as sns

sns.pairplot(data, hue="class")

# %% [markdown]
# ## Exercise 1: Drinks
# data source: https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv

# %%
drinks = pd.read_csv('drinks.csv') # , na_filter=False

drink_cols = ['country', 'beer', 'spirit', 'wine', 'liters', 'continent']
drinks.columns = drink_cols

drinks.head()
# Out:
#        country  beer  spirit  wine  liters continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF
# 3      Andorra   245     138   312    12.4        EU
# 4       Angola   217      57    45     5.9        AF

# %% [markdown]
# ### Basic check
#
# - Column type (Numerical or Categorical)
# - Summary statistics
# - Missing values (`nan`)
# - ...

# %%
# summary statistics of all columns
drinks.describe(include='all')
# Out:
#             country        beer      spirit        wine      liters continent
# count           193  193.000000  193.000000  193.000000  193.000000       170
# unique          193         NaN         NaN         NaN         NaN         5
# top     Afghanistan         NaN         NaN         NaN         NaN        AF
# freq              1         NaN         NaN         NaN         NaN        53
# mean            NaN  106.160622   80.994819   49.450777    4.717098       NaN
# std             NaN  101.143103   88.284312   79.697598    3.773298       NaN
# min             NaN    0.000000    0.000000    0.000000    0.000000       NaN
# 25%             NaN   20.000000    4.000000    1.000000    1.300000       NaN
# 50%             NaN   76.000000   56.000000    8.000000    4.200000       NaN
# 75%             NaN  188.000000  128.000000   59.000000    7.200000       NaN
# max             NaN  376.000000  438.000000  370.000000   14.400000       NaN

# %%
drinks['continent'].value_counts() # AFrica, EU, ASia, OCeania, SouthAmerica
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
drinks.isna().sum() # 23 missing values in `continent` column
# Out:
# country       0
# beer          0
# spirit        0
# wine          0
# liters        0
# continent    23
# dtype: int64

# %%
drinks[drinks.continent.isna()] # check the rows with missing values
# Out:
#                           country  beer  spirit  wine  liters continent
# 5               Antigua & Barbuda   102     128    45     4.9       NaN
# 11                        Bahamas   122     176    51     6.3       NaN
# 14                       Barbados   143     173    36     6.3       NaN
# 17                         Belize   263     114     8     6.8       NaN
# 32                         Canada   240     122   100     8.2       NaN
# 41                     Costa Rica   149      87    11     4.4       NaN
# 43                           Cuba    93     137     5     4.2       NaN
# 50                       Dominica    52     286    26     6.6       NaN
# 51             Dominican Republic   193     147     9     6.2       NaN
# 54                    El Salvador    52      69     2     2.2       NaN
# 68                        Grenada   199     438    28    11.9       NaN
# 69                      Guatemala    53      69     2     2.2       NaN
# ...

# %% [markdown]
# ### Histogram
# Purpose: Showing the distribution of a numerical variable

# %%
# histogram
bins = 10

drinks.beer.plot(kind='hist', bins=bins)
plt.xlabel('Beer Servings')
plt.ylabel('Frequency')
plt.title('Histogram of Beer Servings (nbin=%d)' % bins)
# Out:
# Text(0.5, 1.0, 'Histogram of Beer Servings (nbin=10)')

# %%
# compare with density plot (smooth version of a histogram)
drinks.beer.plot(kind='density', xlim=(0, 400))
# Out:
# <Axes: ylabel='Density'>

# %%
# histogram of beer servings grouped by continent
drinks.hist(column='beer', by='continent')
# plt.tight_layout()
# Out:
# array([[<Axes: title={'center': 'AF'}>, <Axes: title={'center': 'AS'}>],
#        [<Axes: title={'center': 'EU'}>, <Axes: title={'center': 'OC'}>],
#        [<Axes: title={'center': 'SA'}>, <Axes: >]], dtype=object)

# %%
# share the x axes
drinks.hist(column='beer', by='continent', sharex=True)
# Out:
# array([[<Axes: title={'center': 'AF'}>, <Axes: title={'center': 'AS'}>],
#        [<Axes: title={'center': 'EU'}>, <Axes: title={'center': 'OC'}>],
#        [<Axes: title={'center': 'SA'}>, <Axes: >]], dtype=object)

# %%
# share the x and y axes
drinks.hist(column='beer', by='continent', sharex=True, sharey=True)
# Out:
# array([[<Axes: title={'center': 'AF'}>, <Axes: title={'center': 'AS'}>],
#        [<Axes: title={'center': 'EU'}>, <Axes: title={'center': 'OC'}>],
#        [<Axes: title={'center': 'SA'}>, <Axes: >]], dtype=object)

# %%
# change the layout
drinks.hist(column='beer', by='continent', sharex=True, layout=(2, 3))
# Out:
# array([[<Axes: title={'center': 'AF'}>, <Axes: title={'center': 'AS'}>,
#         <Axes: title={'center': 'EU'}>],
#        [<Axes: title={'center': 'OC'}>, <Axes: title={'center': 'SA'}>,
#         <Axes: >]], dtype=object)

# %% [markdown]
# ### Scatter plot
# Purpose: Showing the relationship between two numerical variables

# %%
# scatter plot
drinks.plot(kind='scatter', x='beer', y='wine')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='beer', ylabel='wine'>

# %%
# add transparency
drinks.plot(kind='scatter', x='beer', y='wine', alpha=0.3)
plt.show()

# %%
# scatter matrix of three numerical columns
columns = ['beer', 'spirit', 'wine']
pd.plotting.scatter_matrix(drinks[columns], figsize=(10, 10))
plt.show()

# %% [markdown]
# ### Bar plot
# Purpose: Showing a numerical comparison across different categories

# %%
# count the number of countries in each continent
drinks.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
# compare with bar plot
drinks.continent.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# calculate the mean alcohol amounts for each continent
drinks.groupby('continent').mean()
# Out:
#                  beer      spirit        wine    liters
# continent
# AF          61.471698   16.339623   16.264151  3.007547
# AS          37.045455   60.840909    9.068182  2.170455
# EU         193.777778  132.555556  142.222222  8.617778
# OC          89.687500   58.437500   35.625000  3.381250
# SA         175.083333  114.750000   62.416667  6.308333

# %%
# side-by-side bar plots
drinks.groupby('continent').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='continent'>

# %%
# drop the liters column
drinks.groupby('continent').mean().drop('liters', axis=1).plot(kind='bar')
# Out:
# <Axes: xlabel='continent'>

# %%
# stacked bar plots
drinks.groupby('continent').mean().drop('liters', axis=1).plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='continent'>

# %% [markdown]
# ### Box plot
# Purpose: Showing quartiles and outliers for one or more numerical variables

# %%
# box plot of beer servings
drinks.beer.plot(kind='box')
# Out:
# <Axes: >

# %%
# include multiple variables
drinks.drop('liters', axis=1).plot(kind='box')
# Out:
# <Axes: >

# %%
# box plot of beer servings grouped by continent
drinks.boxplot(column='beer', by='continent')
# Out:
# <Axes: title={'center': 'beer'}, xlabel='continent'>

# %%
# box plot of all numeric columns grouped by continent
drinks.boxplot(by='continent')
# Out:
# array([[<Axes: title={'center': 'beer'}, xlabel='[continent]'>,
#         <Axes: title={'center': 'liters'}, xlabel='[continent]'>],
#        [<Axes: title={'center': 'spirit'}, xlabel='[continent]'>,
#         <Axes: title={'center': 'wine'}, xlabel='[continent]'>]],
#       dtype=object)

# %% [markdown]
# ## Exercise 2: UFO
# data source: https://raw.githubusercontent.com/justmarkham/DAT8/master/data/ufo.csv

# %%
# read in the ufo data
ufo = pd.read_csv('ufo.csv')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
# add two new columns
ufo['Time'] = pd.to_datetime(ufo.Time)
ufo['Year'] = ufo.Time.dt.year
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time  Year
# 0 1930-06-01 22:00:00  1930
# 1 1930-06-30 20:00:00  1930
# 2 1931-02-15 14:00:00  1931
# 3 1931-06-01 13:00:00  1931
# 4 1933-04-18 19:00:00  1933

# %% [markdown]
# ### Line plot
# Purpose: Showing the trend of a numerical variable over time

# %%
# count the number of ufo reports each year (and sort by year)
ufo.Year.value_counts().sort_index()
# Out:
# 1930       2
# 1931       2
# 1933       1
# 1934       1
# 1935       1
#         ...
# 2010    4154
# 2011    5089
# 2012    7263
# 2013    7003
# 2014    5382
# Name: Year, Length: 82, dtype: int64

# %%
# compare with line plot
ufo.Year.value_counts().sort_index().plot()
# Out:
# <Axes: >

# %%
# don't use a line plot when there is no logical ordering
drinks.continent.value_counts().plot()
# Out:
# <Axes: >

# %%
# instead, bar plot is good in this case
drinks.continent.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # Homework: Titanic data exploration
#
# The Titanic dataset (location: `titanic.csv`) contains information about individual passengers aboard the Titanic, including those who survived the Titanic shipwreck. Each row represents one person. The columns describe different attributes about the person including whether they survived, their age, their passenger-class, their sex, the fare they paid, and so on.

# %%
df = pd.read_csv('titanic.csv')
df.head()
# Out:
#   Passenger Class                                             Name     Sex  \
# 0           First                    Allen, Miss. Elisabeth Walton  Female
# 1           First                   Allison, Master. Hudson Trevor    Male
# 2           First                     Allison, Miss. Helen Loraine  Female
# 3           First             Allison, Mr. Hudson Joshua Creighton    Male
# 4           First  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Female
#
#     Age  No of Siblings or Spouses on Board  \
# 0  29.0                                   0
# 1   0.9                                   1
# 2   2.0                                   1
# 3  30.0                                   1
# 4  25.0                                   1
#
#    No of Parents or Children on Board Ticket Number  Passenger Fare    Cabin  \
# 0                                   0         24160           211.3       B5
# 1                                   2        113781           151.6  C22 C26
# ...

# %% [markdown]
# 1. Create a new empty jupyter notebook file.
# 2. Rename the file to `hw1-StudentID-YourName.ipynb`. (e.g., `hw1-12345678-JihoYoon.ipynb`)
# 3. Explore the data to understand the data. During exploration, you may discover ...
#
# - characteristics of the data.
# - data preprocessing directions to make up for missing values, duplicated rows, noise, etc.
# - interesting facts about which characterisitcs of people survived.
